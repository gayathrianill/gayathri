# %% [markdown]
# <a href="https://colab.research.google.com/github/gayathrianill/gayathri/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error,r2_score

data = {
    'Area': [1200,1500,1800,-2400,3000,
             3500,4000,4500,5000,5500],
    'Bedrooms': [2,3,3,4,5,
                 5,6,6,7,7],
    'Age' : [10,5,8,2,1,
             3,2,4,1,2],
    'Distance' : [5,3,4,2,1,
                  2,1,3,2,1],
    'Price' : [250,320,340,450,600,
               650,700,720,800,850]
}

df=pd.DataFrame(data)

print("\nDATASET\n")
print(df)
# Out:
# DATASET
#
#    Area  Bedrooms  Age  Distance  Price
# 0  1200         2   10         5    250
# 1  1500         3    5         3    320
# 2  1800         3    8         4    340
# 3 -2400         4    2         2    450
# 4  3000         5    1         1    600
# 5  3500         5    3         2    650
# 6  4000         6    2         1    700
# 7  4500         6    4         3    720
# 8  5000         7    1         2    800
# 9  5500         7    2         1    850

# %%
X=df[['Area','Bedrooms','Age','Distance']]
y=df['Price']

# %%
model = LinearRegression()

# %%
model.fit(X, y)
y_pred = model.predict(X)

# %%
print("\nMODEL PARAMETERS\n")

print("Intercept:")
print(model.intercept_)

print("\nCoefficients:")
for feature, coef in zip(X.columns, model.coef_):
    print(feature, ":", coef)
# Out:
# MODEL PARAMETERS
#
# Intercept:
# -2.0121773026535266
#
# Coefficients:
# Area : 0.0039027192137843997
# Bedrooms : 118.44840439856472
# Age : 8.020528868276614
# Distance : -16.57903272498052

# %%
print("\nREGRESSION EQUATION\n")

print("Price = ")

for feature, coef in zip(X.columns, model.coef_):
    print(f"({coef:.4f} * {feature}) + ")

print(model.intercept_)
# Out:
# REGRESSION EQUATION
#
# Price =
# (0.0039 * Area) +
# (118.4484 * Bedrooms) +
# (8.0205 * Age) +
# (-16.5790 * Distance) +
# -2.0121773026535266

# %%
mse = mean_squared_error(y, y_pred)

r2 = r2_score(y, y_pred)

print("\nEVALUATION METRICS\n")

print("Mean Squared Error (MSE):", round(mse, 4))

print("R² Score:", round(r2, 4))
# Out:
# EVALUATION METRICS
#
# Mean Squared Error (MSE): 565.1335
# R² Score: 0.9862

# %%
new_house = pd.DataFrame({
    'Area': [2800],
    'Bedrooms': [4],
    'Age': [2],
    'Distance': [2]
})
predicted_price = model.predict(new_house)

print("\nNEW HOUSE PREDICTION\n")

print("Predicted House Price:",
      round(predicted_price[0], 2))
# Out:
# NEW HOUSE PREDICTION
#
# Predicted House Price: 465.59

# %%
plt.figure(figsize=(8,6))

plt.scatter(y,y_pred,color='blue')

plt.plot([y.min(),y.max()],
         [y.min(),y.max()],
         color='red')

plt.xlabel("actual prices")
plt.ylabel("predicted prices")

plt.grid(True)

plt.show()
